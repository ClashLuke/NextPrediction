# %% [markdown]
# <a href="https://colab.research.google.com/github/ClashLuke/BigGAN-PyTorch/blob/master/dual_dropout_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://www.github.com/clashluke/nextprediction --recursive
# Out:
# Cloning into 'nextprediction'...
# ...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 51 (delta 21), reused 47 (delta 17), pack-reused 0
# Unpacking objects: 100% (51/51), done.
# Submodule 'LocAtE' (https://www.github.com/ClashLuke/LocAtE) registered for path 'LocAtE'
# Cloning into '/content/nextprediction/LocAtE'...
# ...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 66 (delta 32), reused 43 (delta 16), pack-reused 0
# Submodule path 'LocAtE': checked out '9557756b9b578e31febe2891533d26ef63a53c2f'

# %%
# !cd nextprediction && python3 main.py
# Out:
# Random Seed:  999
# Sequential(
#   (0): BlockBlock(
#     (block_0): Block(
#       (scale_layer): CatModule(
#         (layer_module): SpectralNorm(
#           (module): Conv1d(6, 90, kernel_size=(1,), stride=(1,))
#         )
#       )
#       (res_module_i): ResModule(
#         (layer_module): Norm(
#           (i_norm): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (module): InceptionBlock(
#             (factorized_conv_0): FactorizedConvModule(
#               (nlin_0): RootTanhModule()
#               (layer_0): SpectralNorm(
#                 (module): Conv1d(6, 1, kernel_size=[1], stride=[1], padding=[0], bias=False)
#               )
#               (nlin_1): RootTanhModule()
#               (layer_1): SpectralNorm(
#                 (module): Conv1d(1, 1, kernel_size=[3], stride=[1], padding=[1], bias=False)
#               )
#               (nlin_2): RootTanhModule()
#               (layer_2): SpectralNorm(
# ...
